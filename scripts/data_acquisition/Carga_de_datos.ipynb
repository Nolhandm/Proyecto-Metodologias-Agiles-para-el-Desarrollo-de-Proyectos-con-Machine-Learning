# %%
# Se importa los paquetes necesarios
import pandas as pd
import requests
import zipfile, os, sys

# %%
# Enlace del archivo
url = "https://databank.worldbank.org/data/download/ESG_CSV.zip"

# Descargar el archivo
response = requests.get(url)
with open('ESG_Dataset.zip', 'wb') as f:
    f.write(response.content)

# %%
# Unzip the dataset
with zipfile.ZipFile('ESG_Dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('ESG_Dataset')

# Delete the archive
os.remove('ESG_Dataset.zip')

# %%
# Se carga el dataset en un DataFrame pandas

ESG_df = pd.read_csv("/content/ESG_Dataset/ESGCSV.csv")
# Supprimer colonnes inutiles
ESG_df.drop(columns=['Country Code', "Indicator Code"], inplace=True)
ESG_df
# Out:
#       Country Name                                     Indicator Name  1960  \
# 0       Arab World  Access to clean fuels and technologies for coo...   NaN
# 1       Arab World            Access to electricity (% of population)   NaN
# 2       Arab World  Adjusted savings: natural resources depletion ...   NaN
# 3       Arab World  Adjusted savings: net forest depletion (% of GNI)   NaN
# 4       Arab World                 Agricultural land (% of land area)   NaN
# ...            ...                                                ...   ...
# 16964     Zimbabwe  Terrestrial and marine protected areas (% of t...   NaN
# 16965     Zimbabwe                         Tree Cover Loss (hectares)   NaN
# 16966     Zimbabwe  Unemployment, total (% of total labor force) (...   NaN
# 16967     Zimbabwe  Unmet need for contraception (% of married wom...   NaN
# 16968     Zimbabwe                 Voice and Accountability: Estimate   NaN
#
#             1961       1962       1963       1964       1965     1966  \
# 0            NaN        NaN        NaN        NaN        NaN      NaN
# 1            NaN        NaN        NaN        NaN        NaN      NaN
# 2            NaN        NaN        NaN        NaN        NaN      NaN
# 3            NaN        NaN        NaN        NaN        NaN      NaN
# 4      30.981414  30.982663  31.007054  31.018001  31.042466  31.0504
# ...          ...        ...        ...        ...        ...      ...
# 16964        NaN        NaN        NaN        NaN        NaN      NaN
# 16965        NaN        NaN        NaN        NaN        NaN      NaN
# 16966        NaN        NaN        NaN        NaN        NaN      NaN
# 16967        NaN        NaN        NaN        NaN        NaN      NaN
# 16968        NaN        NaN        NaN        NaN        NaN      NaN
#
#             1967  ...       2014       2015       2016       2017       2018  \
# 0            NaN  ...  86.705717  86.942778  87.228705  87.390856  87.617862
# 1            NaN  ...  88.832276  89.053852  89.539016  90.662754  89.176939
# 2            NaN  ...  10.050554   6.130655   5.265859   6.245422   8.187714
# 3            NaN  ...   0.084361   0.096672   0.092911   0.102684   0.057123
# 4      31.103223  ...  39.834421  39.872575  39.937814  39.984452  39.969738
# ...          ...  ...        ...        ...        ...        ...        ...
# 16964        NaN  ...        NaN        NaN  27.214542  27.214585  27.214585
# 16965        NaN  ...        NaN        NaN        NaN        NaN        NaN
# 16966        NaN  ...   4.770000   5.412000   5.918000   6.349000   6.767000
# 16967        NaN  ...  10.382129  10.400000        NaN        NaN        NaN
# 16968        NaN  ...  -1.256889  -1.166087  -1.178460  -1.195905  -1.136798
#
#             2019       2020       2021       2022   2023
# 0      87.798740  87.948264  88.092536        NaN    NaN
# 1      90.352802  90.635050  90.845661        NaN    NaN
# 2       7.234436   4.598506        NaN        NaN    NaN
# 3       0.064516   0.075686        NaN        NaN    NaN
# 4      39.907031  39.973290  39.970742        NaN    NaN
# ...          ...        ...        ...        ...    ...
# 16964  27.214747  27.214747  27.214747  27.214747    NaN
# 16965        NaN        NaN        NaN        NaN    NaN
# 16966   7.370000   8.651000   9.540000   9.256000  9.116
# 16967        NaN        NaN        NaN        NaN    NaN
# 16968  -1.163669  -1.113408  -1.135830  -1.102206    NaN
#
# [16969 rows x 66 columns]

# %%
# Cambiamos el DataFrame para poner los indicatores en columnas

# Formato longo
df_long = ESG_df.melt(
    id_vars=["Country Name", "Indicator Name"],
    var_name="Year",
    value_name="Value"
)
# Indicadores en columnas
ESG_ByInd_df = df_long.pivot_table(
    index=["Country Name", "Year"],
    columns="Indicator Name",
    values="Value"
).reset_index()

# Evitar multi-index
ESG_ByInd_df.columns.name = None
ESG_ByInd_df
# Out:
#       Country Name  Year  \
# 0      Afghanistan  1960
# 1      Afghanistan  1961
# 2      Afghanistan  1962
# 3      Afghanistan  1963
# 4      Afghanistan  1964
# ...            ...   ...
# 15275     Zimbabwe  2019
# 15276     Zimbabwe  2020
# 15277     Zimbabwe  2021
# 15278     Zimbabwe  2022
# 15279     Zimbabwe  2023
#
#        Access to clean fuels and technologies for cooking (% of population)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 15275                                               30.2
# 15276                                               30.3
# 15277                                               30.3
# 15278                                                NaN
# 15279                                                NaN
#
#        Access to electricity (% of population)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 15275                                46.682095
# 15276                                52.747667
# 15277                                48.979927
# 15278                                      NaN
# 15279                                      NaN
#
#        Adjusted savings: natural resources depletion (% of GNI)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 15275                                           4.088445
# 15276                                           4.108902
# 15277                                           5.053145
# 15278                                                NaN
# 15279                                                NaN
#
#        Adjusted savings: net forest depletion (% of GNI)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 15275                                           2.028044
# 15276                                           2.315889
# 15277                                           1.865862
# 15278                                                NaN
# 15279                                                NaN
#
#        Agricultural land (% of land area)  \
# 0                                     NaN
# 1                               57.878356
# 2                               57.955016
# 3                               58.031676
# 4                               58.116002
# ...                                   ...
# 15275                           41.876696
# 15276                           41.876696
# 15277                           41.876696
# 15278                                 NaN
# 15279                                 NaN
#
#        Agriculture, forestry, and fishing, value added (% of GDP)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 15275                                           9.819262
# 15276                                           8.772859
# 15277                                           8.849899
# 15278                                           7.191922
# 15279                                                NaN
#
#        Annual freshwater withdrawals, total (% of internal resources)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 15275                                          30.761677
# 15276                                          30.761677
# 15277                                                NaN
# 15278                                                NaN
# 15279                                                NaN
#
#        Annualized average growth rate in per capita real survey mean consumption or income, total population (%)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 15275                                               1.03
# 15276                                                NaN
# 15277                                                NaN
# 15278                                                NaN
# 15279                                                NaN
#
#        ...  School enrollment, primary (% gross)  \
# 0      ...                                   NaN
# 1      ...                                   NaN
# 2      ...                                   NaN
# 3      ...                                   NaN
# 4      ...                                   NaN
# ...    ...                                   ...
# 15275  ...                             97.476608
# 15276  ...                             97.384163
# 15277  ...                             96.015144
# 15278  ...                                   NaN
# 15279  ...                                   NaN
#
#        School enrollment, primary and secondary (gross), gender parity index (GPI)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 15275                                                NaN
# 15276                                                NaN
# 15277                                                NaN
# 15278                                                NaN
# 15279                                                NaN
#
#        Scientific and technical journal articles  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 15275                                     431.62
# 15276                                     480.16
# 15277                                        NaN
# 15278                                        NaN
# 15279                                        NaN
#
#        Standardised Precipitation-Evapotranspiration Index  \
# 0                                               0.761520
# 1                                              -0.076736
# 2                                              -0.665528
# 3                                               0.216942
# 4                                               0.488956
# ...                                                  ...
# 15275                                          -0.301619
# 15276                                          -0.204054
# 15277                                          -0.549090
# 15278                                                NaN
# 15279                                                NaN
#
#        Strength of legal rights index (0=weak to 12=strong)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 15275                                                6.0
# 15276                                                NaN
# 15277                                                NaN
# 15278                                                NaN
# 15279                                                NaN
#
#        Terrestrial and marine protected areas (% of total territorial area)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 15275                                          27.214747
# 15276                                          27.214747
# 15277                                          27.214747
# 15278                                          27.214747
# 15279                                                NaN
#
#        Tree Cover Loss (hectares)  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 15275                         NaN
# 15276                         NaN
# 15277                         NaN
# 15278                         NaN
# 15279                         NaN
#
#        Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 15275                                              7.370
# 15276                                              8.651
# 15277                                              9.540
# 15278                                              9.256
# 15279                                              9.116
#
#        Unmet need for contraception (% of married women ages 15-49)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 15275                                                NaN
# 15276                                                NaN
# 15277                                                NaN
# 15278                                                NaN
# 15279                                                NaN
#
#        Voice and Accountability: Estimate
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 15275                           -1.163669
# 15276                           -1.113408
# 15277                           -1.135830
# 15278                           -1.102206
# 15279                                 NaN
#
# [15280 rows x 73 columns]
